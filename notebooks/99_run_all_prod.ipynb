# %%
catalog = "etl_demo_prod"

spark.sql(f"USE CATALOG {catalog}")
spark.sql("CREATE SCHEMA IF NOT EXISTS bronze")
spark.sql("CREATE SCHEMA IF NOT EXISTS silver_staging")
spark.sql("CREATE SCHEMA IF NOT EXISTS silver")
spark.sql("CREATE SCHEMA IF NOT EXISTS gold")
spark.sql("CREATE SCHEMA IF NOT EXISTS control")

dbutils.notebook.run("./01_bronze_ingest", 0, {"catalog": catalog})
dbutils.notebook.run("./02_staging_prepare_sql", 0,{"catalog": catalog})
dbutils.notebook.run("./03_silver_scd2_merge_sql", 0,{"catalog": catalog})
dbutils.notebook.run("./04_gold_views_and_kpis_sql", 0,{"catalog": catalog})
dbutils.notebook.run("./05_data_quality_checks_sql", 0,{"catalog": catalog})
