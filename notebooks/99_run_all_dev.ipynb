# %%
dbutils.widgets.text("env", "dev")
env = dbutils.widgets.get("env")
schema = f"etl_demo_{env}"

spark.sql(f"CREATE SCHEMA IF NOT EXISTS {schema}.bronze")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {schema}.silver_staging")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {schema}.silver")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {schema}.gold")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {schema}.control")

# IMPORTANT: your notebooks must reference schema variable OR be written with USE SCHEMA inside.
# If not refactored yet, do it next step.

dbutils.notebook.run("./01_bronze_ingest", 0, {"env": env})
dbutils.notebook.run("./02_staging_prepare_sql", 0)
dbutils.notebook.run("./05_data_quality_checks_sql", 0)
dbutils.notebook.run("./03_silver_scd2_merge_sql", 0)
dbutils.notebook.run("./04_gold_views_and_kpis_sql", 0)
dbutils.notebook.run("./05_data_quality_checks_sql", 0)
